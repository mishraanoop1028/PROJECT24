# %%
Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
Matplotlib.
ANS-Matplotlib is a Python library that is used for data visualization. It provides a variety of tools for creating graphs, plots, charts, and other visual representations of data.

Matplotlib is used for a wide range of applications, including scientific research, finance, engineering, and data analysis. It is a popular choice for data visualization due to its flexibility, versatility, and ease of use.

The Pyplot module of Matplotlib provides a simple and intuitive interface for creating a wide range of plots. Some of the most commonly used plots that can be created using Pyplot are:

1. Line plot - Used to visualize the trend of a variable over time or another continuous variable.
2. Scatter plot - Used to show the relationship between two variables by displaying them as points on a two-dimensional plane.
3. Bar chart - Used to compare categorical data across different categories.
4. Histogram - Used to visualize the distribution of a continuous variable by grouping it into bins and displaying the frequency of each bin.
5. Pie chart - Used to display the relative proportions of different categories within a data set.

These are just a few examples of the many types of
plots that can be created using Matplotlib. The library 
also provides support for more complex plots, such as 3D plots,
heatmaps, and contour plots, among others.

# %%
Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
plot a scatter plot.

import numpy as np

np.random.seed(3)

x = 3 + np.random.normal(0, 2, 50)

y = 3 + np.random.normal(0, 2, len(x))

Note: Also add title, xlabel, and ylabel to the plot.
ANS-
A scatter plot is a type of plot used to display the relationship between two variables. It consists of a set of points, where each point represents a pair of values for the two variables being plotted. The position of the point on the plot corresponds to the values of the two variables, with one variable plotted along the x-axis and the other plotted along the y-axis.

Here's how you can use the provided code to generate data for x and y and plot a scatter plot using Matplotlib:

```python
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)

x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

plt.scatter(x, y)
plt.title("Scatter plot of x and y")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()
```

In this example, we first import the necessary modules, NumPy and Matplotlib. We then set the random seed to ensure that the same data is generated each time the code is run.

Next, we generate the data for x and y using NumPy's `random.normal()` function. This function generates random numbers from a normal distribution with the specified mean and standard deviation. We use a mean of 3 and a standard deviation of 2 for both x and y.

Finally, we plot the scatter plot using Matplotlib's `scatter()` function, with x and y as the two variables being plotted. We also add a title, x-axis label, and y-axis label to the plot using Matplotlib's `title()`, `xlabel()`, and `ylabel()` functions, respectively. The `show()` function is used to display the plot.

# %%
Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

Use the following data:

import numpy as np

For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and  y = np.array([0, 100, 200, 300, 400, 500])

For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])

For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])

For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])
ANS-The `subplot()` function in Matplotlib is used to create multiple plots in a single figure. It takes three arguments: the number of rows of subplots, the number of columns of subplots, and the index of the subplot to create.

Here's an example of how to create four line plots using the `subplot()` function:

```python
import numpy as np
import matplotlib.pyplot as plt

# Data for line 1
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

# Data for line 2
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

# Data for line 3
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

# Data for line 4
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2)

# Plot line 1 in the first subplot
axs[0, 0].plot(x1, y1)
axs[0, 0].set_title('Line 1')

# Plot line 2 in the second subplot
axs[0, 1].plot(x2, y2)
axs[0, 1].set_title('Line 2')

# Plot line 3 in the third subplot
axs[1, 0].plot(x3, y3)
axs[1, 0].set_title('Line 3')

# Plot line 4 in the fourth subplot
axs[1, 1].plot(x4, y4)
axs[1, 1].set_title('Line 4')

# Add a title for the entire figure
fig.suptitle('Four line plots')

# Display the plot
plt.show()
```

In this example, we first import the necessary modules, NumPy and Matplotlib. We then define the data for the four line plots using NumPy's `array()` function.

Next, we create a 2x2 grid of subplots using Matplotlib's `subplots()` function, and store the resulting figure and axes objects in variables `fig` and `axs`, respectively.

We then plot each line in its corresponding subplot using the `plot()` function and set the title for each subplot using the `set_title()` function. Finally, we add a title for the entire figure using the `suptitle()` function, and display the plot using the `show()` function.

The resulting plot will have four line plots, each in its own subplot within a single figure.

# %%
Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot. 

import numpy as np

company = np.array(["Apple", "Microsoft", "Google", "AMD"])

profit = np.array([3000, 8000, 1000, 10000])
ANS-A bar plot is a visualization of data that uses bars to represent the values of each category or group. It is used to compare the data values of different groups or categories.

A horizontal bar plot is a bar plot with the bars arranged horizontally instead of vertically.

Here's how to plot a bar plot and a horizontal bar plot using the given data:

```
import numpy as np
import matplotlib.pyplot as plt

# Data
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Bar plot
plt.bar(company, profit)
plt.title("Company Profit")
plt.xlabel("Company")
plt.ylabel("Profit")
plt.show()

# Horizontal bar plot
plt.barh(company, profit)
plt.title("Company Profit")
plt.xlabel("Profit")
plt.ylabel("Company")
plt.show()
```

The first plot will display a vertical bar plot with the x-axis showing the company names and the y-axis showing the profit values. The second plot will display a horizontal bar plot with the y-axis showing the company names and the x-axis showing the profit values.

# %%
Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

box1 = np.random.normal(100, 10, 200)

box2 = np.random.normal(90, 20, 200)
ANS-A box plot is a graphical representation of the distribution of data based on five number summary: minimum, first quartile, median, third quartile, and maximum. It is used to identify outliers and to visualize the spread of data and to compare distributions between different groups.

Here's how to plot a box plot using the given data:

```
import numpy as np
import matplotlib.pyplot as plt

# Data
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# Create a figure and axis
fig, ax = plt.subplots()

# Create a boxplot
bp = ax.boxplot([box1, box2], labels=['Box 1', 'Box 2'])

# Add title and y-label
ax.set_title('Boxplot of Box 1 and Box 2')
ax.set_ylabel('Value')

# Show the plot
plt.show()
```

The plot will display a box plot with two boxes side by side representing the distributions of box1 and box2. The x-axis shows the box names and the y-axis shows the values. The box represents the interquartile range (IQR), with the line inside the box representing the median. The whiskers extend from the box to the minimum and maximum values, excluding outliers, which are displayed as individual points.
